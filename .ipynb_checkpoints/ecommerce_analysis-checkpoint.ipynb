# %%
import pandas as pd

# %%
# reading from csv file
df = pd.read_csv('ecommerce/sales_data.csv')
df.columns
# Out:
# Index(['Order ID', 'Product Category', 'Product', 'Quantity Ordered',
#        'Price Each', 'Order Date', 'Purchase Address', 'Month', 'Sales',
#        'City', 'Hour', 'Time of Day'],
#       dtype='object')

# %%
data = {
    'apples':[3,2,4,5],
    'oranges':[1,5,6,2]
}
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        1
# 1       2        5
# 2       4        6
# 3       5        2

# %%
# changing the index
purchases = pd.DataFrame(data , index = ['June','Robert','Kill','Kull'])
purchases
# Out:
#         apples  oranges
# June         3        1
# Robert       2        5
# Kill         4        6
# Kull         5        2

# %%
# locating using index
purchases.loc['June']
# Out:
# apples     3
# oranges    1
# Name: June, dtype: int64

# %%
# saving the dataframe to a csv file
purchases.to_csv('customer_purchases.csv')

# %%
# reading from the csv file created
purchases = pd.read_csv('customer_purchases.csv', index_col= 0) # set the index col as first one !!
purchases
# Out:
#         apples  oranges
# June         3        1
# Robert       2        5
# Kill         4        6
# Kull         5        2

# %%
# saving data to json file
purchases.to_json('customer_purchases.json')

# %%
# reading from the json file 
purchases2 = pd.read_json('customer_purchases.json')
purchases2
# Out:
#         apples  oranges
# June         3        1
# Robert       2        5
# Kill         4        6
# Kull         5        2

# %%
df.shape
# Out:
# (185950, 13)

# %%
temp_df = pd.concat([df,df],ignore_index = True)
temp_df.shape
# Out:
# (371900, 13)

# %%
temp_df.head(2)
# Out:
#    Unnamed: 0  Order ID       Product Category             Product  \
# 0           0    295665  Laptops and Computers  Macbook Pro Laptop
# 1           1    295666        Home Appliances  LG Washing Machine
#
#    Quantity Ordered  Price Each        Order Date  \
# 0                 1      1700.0  30-12-2019 00:01
# 1                 1       600.0  29-12-2019 07:03
#
#                          Purchase Address  Month   Sales            City  \
# 0  136 Church St, New York City, NY 10001     12  1700.0   New York City
# 1     562 2nd St, New York City, NY 10001     12   600.0   New York City
#
#    Hour Time of Day
# 0     0       Night
# 1     7     Morning

# %%
# setting the index later
temp_df.set_index('Order ID',inplace = True)
temp_df.head(2)
# Out:
#           Unnamed: 0       Product Category             Product  \
# Order ID
# 295665             0  Laptops and Computers  Macbook Pro Laptop
# 295666             1        Home Appliances  LG Washing Machine
#
#           Quantity Ordered  Price Each        Order Date  \
# Order ID
# 295665                   1      1700.0  30-12-2019 00:01
# 295666                   1       600.0  29-12-2019 07:03
#
#                                 Purchase Address  Month   Sales  \
# Order ID
# 295665    136 Church St, New York City, NY 10001     12  1700.0
# 295666       562 2nd St, New York City, NY 10001     12   600.0
#
#                     City  Hour Time of Day
# Order ID
# 295665     New York City     0       Night
# 295666     New York City     7     Morning

# %%
temp_df.columns
# Out:
# Index(['Unnamed: 0', 'Product Category', 'Product', 'Quantity Ordered',
#        'Price Each', 'Order Date', 'Purchase Address', 'Month', 'Sales',
#        'City', 'Hour', 'Time of Day'],
#       dtype='object')

# %%
temp_df.shape
# Out:
# (371900, 13)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product Category', 'Product', 'Quantity Ordered',
#        'Price Each', 'Order Date', 'Purchase Address', 'Month', 'Sales',
#        'City', 'Hour', 'Time of Day'],
#       dtype='object')

# %%
# renaming the columns 
df.columns = [column.replace(' ','_').lower() for column in df.columns]
df.columns
# Out:
# Index(['order_id', 'product_category', 'product', 'quantity_ordered',
#        'price_each', 'order_date', 'purchase_address', 'month', 'sales',
#        'city', 'hour', 'time_of_day'],
#       dtype='object')

# %%
df.isnull().sum() # checks if null values present in columns and at the end gives the sum of null values
# Out:
# order_id            0
# product_category    0
# product             0
# quantity_ordered    0
# price_each          0
# order_date          0
# purchase_address    0
# month               0
# sales               0
# city                0
# hour                0
# time_of_day         0
# dtype: int64

# %%
df.dropna()
# Out:
#         order_id       product_category                 product  \
# 0         295665  Laptops and Computers      Macbook Pro Laptop
# 1         295666        Home Appliances      LG Washing Machine
# 2         295667        Charging Cables    USB-C Charging Cable
# 3         295668               Monitors        27in FHD Monitor
# 4         295669        Charging Cables    USB-C Charging Cable
# ...          ...                    ...                     ...
# 185945    222905               Batterie  AAA Batteries (4-pack)
# 185946    222906               Monitors        27in FHD Monitor
# 185947    222907        Charging Cables    USB-C Charging Cable
# 185948    222908        Charging Cables    USB-C Charging Cable
# 185949    222909               Batterie  AAA Batteries (4-pack)
#
#         quantity_ordered  price_each        order_date  \
# 0                      1     1700.00  30-12-2019 00:01
# 1                      1      600.00  29-12-2019 07:03
# ...

# %%
df['product_category'].describe()
# Out:
# count            185950
# unique                8
# top       Audio Devices
# freq              47756
# Name: product_category, dtype: object

# %%
df['product_category'].value_counts().head(5)
# Out:
# product_category
# Audio Devices             47756
# Charging Cables           43561
# Batterie                  41218
# Monitors                  24019
# Phones and Accessories    14432
# Name: count, dtype: int64

# %%
# select only numeric datatypes
df2 = df.select_dtypes(include = ['number'])

# %%
df2.head(2)
# Out:
#    order_id  quantity_ordered  price_each  month   sales  hour
# 0    295665                 1      1700.0     12  1700.0     0
# 1    295666                 1       600.0     12   600.0     7

# %%
df2.corr()
# Out:
#                   order_id  quantity_ordered  price_each     month     sales  \
# order_id          1.000000          0.000702   -0.002857  0.993063 -0.002949
# quantity_ordered  0.000702          1.000000   -0.148272  0.000791 -0.139417
# price_each       -0.002857         -0.148272    1.000000 -0.003375  0.999203
# month             0.993063          0.000791   -0.003375  1.000000 -0.003466
# sales            -0.002949         -0.139417    0.999203 -0.003466  1.000000
# hour              0.001175         -0.002218    0.001721  0.001731  0.001668
#
#                       hour
# order_id          0.001175
# quantity_ordered -0.002218
# price_each        0.001721
# month             0.001731
# sales             0.001668
# hour              1.000000

# %%
df.product_category.value_counts()
# Out:
# product_category
# Audio Devices             47756
# Charging Cables           43561
# Batterie                  41218
# Monitors                  24019
# Phones and Accessories    14432
# Laptops and Computers      8852
# Entertainment Devices      4800
# Home Appliances            1312
# Name: count, dtype: int64

# %%
type(df[['product_category']])
# double brackets gives a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['product_category'])
# Out:
# pandas.core.series.Series

# %%
# loc practice
df.head(2)
# Out:
#    order_id       product_category             product  quantity_ordered  \
# 0    295665  Laptops and Computers  Macbook Pro Laptop                 1
# 1    295666        Home Appliances  LG Washing Machine                 1
#
#    price_each        order_date                        purchase_address  \
# 0      1700.0  30-12-2019 00:01  136 Church St, New York City, NY 10001
# 1       600.0  29-12-2019 07:03     562 2nd St, New York City, NY 10001
#
#    month   sales            city  hour time_of_day
# 0     12  1700.0   New York City     0       Night
# 1     12   600.0   New York City     7     Morning

# %%
df.set_index('product_category',inplace = True)

# %%
df.head(2)
# Out:
#                        order_id             product  quantity_ordered  \
# product_category
# Laptops and Computers    295665  Macbook Pro Laptop                 1
# Home Appliances          295666  LG Washing Machine                 1
#
#                        price_each        order_date  \
# product_category
# Laptops and Computers      1700.0  30-12-2019 00:01
# Home Appliances             600.0  29-12-2019 07:03
#
#                                              purchase_address  month   sales  \
# product_category
# Laptops and Computers  136 Church St, New York City, NY 10001     12  1700.0
# Home Appliances           562 2nd St, New York City, NY 10001     12   600.0
#
#                                  city  hour time_of_day
# product_category
# Laptops and Computers   New York City     0       Night
# Home Appliances         New York City     7     Morning

# %%
df.loc["Home Appliances"]
# Out:
#                   order_id             product  quantity_ordered  price_each  \
# product_category
# Home Appliances     295666  LG Washing Machine                 1       600.0
# Home Appliances     295689  LG Washing Machine                 1       600.0
# Home Appliances     296329  LG Washing Machine                 1       600.0
# Home Appliances     296376            LG Dryer                 1       600.0
# Home Appliances     296472            LG Dryer                 1       600.0
# ...                    ...                 ...               ...         ...
# Home Appliances     222748            LG Dryer                 1       600.0
# Home Appliances     222835  LG Washing Machine                 1       600.0
# Home Appliances     222839  LG Washing Machine                 1       600.0
# Home Appliances     222876  LG Washing Machine                 1       600.0
# Home Appliances     222885            LG Dryer                 1       600.0
#
# ...

# %%
type(df.iloc[1])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1:3]
# Out:
#                   order_id               product  quantity_ordered  \
# product_category
# Home Appliances     295666    LG Washing Machine                 1
# Charging Cables     295667  USB-C Charging Cable                 1
#
#                   price_each        order_date  \
# product_category
# Home Appliances       600.00  29-12-2019 07:03
# Charging Cables        11.95  12/12/2019 18:21
#
#                                       purchase_address  month   sales  \
# product_category
# Home Appliances    562 2nd St, New York City, NY 10001     12  600.00
# Charging Cables   277 Main St, New York City, NY 10001     12   11.95
#
#                             city  hour time_of_day
# product_category
# Home Appliances    New York City     7     Morning
# Charging Cables    New York City    18     Evening

# %%
condition = (df['product']=='LG Washing Machine')
condition
# Out:
# product_category
# Laptops and Computers    False
# Home Appliances           True
# Charging Cables          False
# Monitors                 False
# Charging Cables          False
#                          ...
# Batterie                 False
# Monitors                 False
# Charging Cables          False
# Charging Cables          False
# Batterie                 False
# Name: product, Length: 185950, dtype: bool

# %%
condition.head()
# Out:
# product_category
# Laptops and Computers    False
# Home Appliances           True
# Charging Cables          False
# Monitors                 False
# Charging Cables          False
# Name: product, dtype: bool

# %%
df[df.index.isin(['Home Appliances'])].head(2)
# Out:
#                   order_id             product  quantity_ordered  price_each  \
# product_category
# Home Appliances     295666  LG Washing Machine                 1       600.0
# Home Appliances     295689  LG Washing Machine                 1       600.0
#
#                         order_date                      purchase_address  \
# product_category
# Home Appliances   29-12-2019 07:03   562 2nd St, New York City, NY 10001
# Home Appliances   24-12-2019 11:21  173 Lake St, San Francisco, CA 94016
#
#                   month  sales            city  hour time_of_day
# product_category
# Home Appliances      12  600.0   New York City     7     Morning
# Home Appliances      12  600.0   San Francisco    11     Morning

# %%
df[df.index.isin(['Charging Cables','Monitors'])].head(2)
# Out:
#                   order_id               product  quantity_ordered  \
# product_category
# Charging Cables     295667  USB-C Charging Cable                 1
# Monitors            295668      27in FHD Monitor                 1
#
#                   price_each        order_date  \
# product_category
# Charging Cables        11.95  12/12/2019 18:21
# Monitors              149.99  22-12-2019 15:13
#
#                                       purchase_address  month   sales  \
# product_category
# Charging Cables   277 Main St, New York City, NY 10001     12   11.95
# Monitors           410 6th St, San Francisco, CA 94016     12  149.99
#
#                             city  hour time_of_day
# product_category
# Charging Cables    New York City    18     Evening
# Monitors           San Francisco    15   Afternoon

# %%
df[((df['product'] == 'USB-C Charging Cable' )|( df['city']=='New York City'))& (df['quantity_ordered']>5)]
# Out:
#                   order_id               product  quantity_ordered  \
# product_category
# Charging Cables     186997  USB-C Charging Cable                 6
#
#                   price_each        order_date  \
# product_category
# Charging Cables        11.95  23-04-2019 21:54
#
#                                     purchase_address  month  sales      city  \
# product_category
# Charging Cables   733 Chestnut St, Seattle, WA 98101      4   71.7   Seattle
#
#                   hour time_of_day
# product_category
# Charging Cables     21     Evening

# %%
def charging_alot(x):
    if x>=3:
        return 'wallah'
    else:
        return 'hola'
